# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelNSO/Projeto-Percep-o-sobre-o-uso-seguro-da-Internet/blob/main/Percep%C3%A7%C3%A3oSobreSeguran%C3%A7aNaInternet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Técnico de desenvolvimento de sistemas** - TDS 3A - IFB Campus Brasília
#
# Professora: **Kadidja Valéria**
#
#
# Disciplina: **Desenvolvimento web**
#
#
# Projeto: **Percepção sobre o uso seguro da Internet**
#
# ![Leonardo_Phoenix_10_Create_a_modern_and_conceptual_illustratio_3.jpg](data:image/jpeg;base64,...)
#
#
# Alunos:
#
# **João Pedro Basileu Jorge,**
#
# **Kamila das Graças de Paula Braga e**
#
# **Rafael Nunes de Sousa**
#
#
# Link para o GitHub: https://github.com/RafaelNSO/Projeto-Percep-o-sobre-o-uso-seguro-da-Internet.git

# %% [markdown]
# ### 1. Apresente em tela (output) toda a base de dados.

# %%
# Carregamos o DataFrame que contém a percepção de pais, responsáveis, crianças e adolescentes
# sobre o uso seguro da Internet em diferentes situações.
# Os dados analisam preocupações comuns e boas práticas de segurança digital adotadas por cada grupo.

# Por exemplo, a resposta mais frequente entre ambos os grupos foi "Não falar com pessoas desconhecidas",
# evidenciando uma forte conscientização sobre riscos de interação online.
# Já no quesito "Cuidado com vírus", crianças e adolescentes demonstraram maior preocupação
# com a segurança de seus dispositivos em comparação aos adultos, o que sugere um nível maior de
# exposição e conhecimento sobre ameaças cibernéticas.

# A análise desses dados permite identificar padrões e diferenças na percepção de segurança digital,
# auxiliando na criação de estratégias educacionais para um uso mais seguro da Internet.

import pandas as pd

percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela
percepcao_sobre_o_uso_seguro_da_internet_df #Exibir a tabela
# Out:
#                                             Resposta  \
# 0                Não falar com pessoas desconhecidas
# 1  Não entrar em sites que tenham conteúdos sexua...
# 2        Privacidade/Não passar informações pessoais
# 3        Sites inapropriados para a idade dos filhos
# 4          Não entrar em sites com conteúdo violento
# 5                                  Cuidado com vírus
# 6                             Ter cuidado com senhas
# 7                            Ter cuidado com hackers
# 8                                             Outros
# 9                                            Não sei
#
#    Pais ou Responsáveis (% sobre o total de pais ou responsáveis)  \
# 0                                                 55
# 1                                                 32
# 2                                                 31
# 3                                                 31
# 4                                                 17
# ...

# %% [markdown]
# ### 2. Apresente o tamanho do seu dataframe (quantas colunas x linhas).

# %%
import pandas as pd

# Carregamos o DataFrame que contém os dados sobre a percepção do uso seguro da Internet.
percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela

# O método .shape retorna uma tupla com a quantidade de linhas e colunas do DataFrame.
# Isso nos permite entender a dimensão dos dados disponíveis para análise.
num_linhas, num_colunas = percepcao_sobre_o_uso_seguro_da_internet_df.shape


print(f"O DataFrame tem {num_linhas} linhas e {num_colunas} colunas.")
print("--------------------------------------")

# O atributo .size retorna o número total de elementos no DataFrame (linhas x colunas).
# Isso ajuda a avaliar o volume total de informações armazenadas.
print("Tamanho do DataFrame: ", percepcao_sobre_o_uso_seguro_da_internet_df.size) #Exibir tamanho do DataFrame
# Out:
# O DataFrame tem 10 linhas e 3 colunas.
# --------------------------------------
# Tamanho do DataFrame:  30

# %% [markdown]
# ### 3. Acesse a linha (x) e apresente em tela todas as características do item

# %%
# O código a seguir exibe uma linha específica do DataFrame, permitindo a visualização de um conjunto particular de dados.
# Neste caso, a função iloc[[0]] é usada para acessar e exibir a primeira linha da tabela (index 0), que pode conter informações
#importantes sobre a percepção do uso seguro da internet.
import pandas as pd

percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela

percepcao_sobre_o_uso_seguro_da_internet_df.iloc[[0]] #Exibir a linha específica
# Out:
#                               Resposta  \
# 0  Não falar com pessoas desconhecidas
#
#    Pais ou Responsáveis (% sobre o total de pais ou responsáveis)  \
# 0                                                 55
#
#    Crianças e adolescentes (% sobre o total de usuários de Internet de 9 a 16 anos)
# 0                                                 52

# %% [markdown]
# ### 4. Verifique se o dataframe está vazio.

# %%
# O código a seguir verifica se o DataFrame está vazio, ou seja, se não contém nenhuma linha de dados.
# A função .empty retorna um valor booleano (True ou False) indicando se o DataFrame está vazio.
# Neste caso, o resultado é impresso na tela para facilitar a verificação.

import pandas as pd

percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela

print(percepcao_sobre_o_uso_seguro_da_internet_df.empty) #Usando empty para verificar se esta vazio
# Out:
# False

# %% [markdown]
# ### 5. Apresente em tela os 5 primeiros registros da base de dados.

# %%
# O código a seguir utiliza a função .head() para exibir os primeiros 5 registros do DataFrame, facilitando a visualização inicial dos dados.
# Isso permite verificar rapidamente as primeiras linhas da tabela, ajudando a entender a estrutura dos dados carregados.
import pandas as pd

percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela

percepcao_sobre_o_uso_seguro_da_internet_df.head() # usando head para exibir os 5 primeiros registros
# Out:
#                                             Resposta  \
# 0                Não falar com pessoas desconhecidas
# 1  Não entrar em sites que tenham conteúdos sexua...
# 2        Privacidade/Não passar informações pessoais
# 3        Sites inapropriados para a idade dos filhos
# 4          Não entrar em sites com conteúdo violento
#
#    Pais ou Responsáveis (% sobre o total de pais ou responsáveis)  \
# 0                                                 55
# 1                                                 32
# 2                                                 31
# 3                                                 31
# 4                                                 17
#
#    Crianças e adolescentes (% sobre o total de usuários de Internet de 9 a 16 anos)
# 0                                                 52
# 1                                                 22
# 2                                                 30
# 3                                                 29
# ...

# %% [markdown]
# ### 6. Exclua um item (linha) de sua base de dados

# %%
# O código a seguir utiliza a função .drop() para excluir a primeira linha do DataFrame, identificada pelo índice 0.
# Isso pode ser útil caso a primeira linha contenha dados indesejados ou seja uma linha de cabeçalho que não deve ser considerada na análise.
# Após a exclusão, o DataFrame atualizado é exibido.
import pandas as pd

percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela

percepcao_sobre_o_uso_seguro_da_internet_df = percepcao_sobre_o_uso_seguro_da_internet_df.drop(0) #Usando drop para excluir uma linhas
percepcao_sobre_o_uso_seguro_da_internet_df
# Out:
#                                             Resposta  \
# 1  Não entrar em sites que tenham conteúdos sexua...
# 2        Privacidade/Não passar informações pessoais
# 3        Sites inapropriados para a idade dos filhos
# 4          Não entrar em sites com conteúdo violento
# 5                                  Cuidado com vírus
# 6                             Ter cuidado com senhas
# 7                            Ter cuidado com hackers
# 8                                             Outros
# 9                                            Não sei
#
#    Pais ou Responsáveis (% sobre o total de pais ou responsáveis)  \
# 1                                                 32
# 2                                                 31
# 3                                                 31
# 4                                                 17
# 5                                                 11
# 6                                                  7
# ...

# %% [markdown]
# ### 7.Adicione um item (linha) na sua base de dados.

# %%
# O código a seguir adiciona um novo dado fictício sobre a percepção de segurança em relação a aplicativos não confiáveis ao DataFrame.
# O novo dado contém uma resposta específica sobre o comportamento recomendado em relação ao compartilhamento de dados pessoais,
# com porcentagens relacionadas à percepção de pais/responsáveis e crianças/adolescentes.
# A função pd.DataFrame() é usada para criar um novo DataFrame com esse dado, e a função pd.concat() adiciona esse novo dado ao DataFrame original,
# garantindo que o índice seja atualizado com o parâmetro ignore_index=True.
# Com esse novo dado, podemos realizar uma análise comparativa entre as percepções de segurança entre pais/responsáveis e os usuários mais jovens,
# além de verificar tendências e identificar áreas em que a conscientização sobre segurança digital pode ser mais eficaz.
import pandas as pd

percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela

# Novo dado fictício sobre apps não confiáveis
novo_dado = {
    "Resposta": "Evitar compartilhar dados pessoais com apps não confiáveis",
    "Pais ou Responsáveis (% sobre o total de pais ou responsáveis)": 35,
    "Crianças e adolescentes (% sobre o total de usuários de Internet de 9 a 16 anos)": 25
}

# Converter o novo dado em um DataFrame
novo_dado_df = pd.DataFrame([novo_dado])

# Adicionar ao DataFrame
percepcao_sobre_o_uso_seguro_da_internet_df = pd.concat([percepcao_sobre_o_uso_seguro_da_internet_df, novo_dado_df], ignore_index=True)

percepcao_sobre_o_uso_seguro_da_internet_df
# Out:
#                                              Resposta  \
# 0                 Não falar com pessoas desconhecidas
# 1   Não entrar em sites que tenham conteúdos sexua...
# 2         Privacidade/Não passar informações pessoais
# 3         Sites inapropriados para a idade dos filhos
# 4           Não entrar em sites com conteúdo violento
# 5                                   Cuidado com vírus
# 6                              Ter cuidado com senhas
# 7                             Ter cuidado com hackers
# 8                                              Outros
# 9                                             Não sei
# 10  Evitar compartilhar dados pessoais com apps nã...
#
#     Pais ou Responsáveis (% sobre o total de pais ou responsáveis)  \
# 0                                                  55
# 1                                                  32
# 2                                                  31
# 3                                                  31
# ...

# %% [markdown]
# ### 8.Transponha a coluna para a linha em sua base de dados

# %%
# O código a seguir transpõe a tabela, ou seja, converte as colunas em linhas e vice-versa.
# A função .T é utilizada para realizar essa transposição, o que pode ser útil em alguns casos para facilitar a análise de dados,
# especialmente quando se deseja que as informações das colunas sejam tratadas como registros individuais.
# Após a transposição, a tabela modificada é exibida.
import pandas as pd

percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela

percepcao_sobre_o_uso_seguro_da_internet_df = percepcao_sobre_o_uso_seguro_da_internet_df.T #usando o T para transpor a tabela

percepcao_sobre_o_uso_seguro_da_internet_df
# Out:
#                                                                                       0  \
# Resposta                                            Não falar com pessoas desconhecidas
# Pais ou Responsáveis (% sobre o total de pais o...                                   55
# Crianças e adolescentes (% sobre o total de usu...                                   52
#
#                                                                                                     1  \
# Resposta                                            Não entrar em sites que tenham conteúdos sexua...
# Pais ou Responsáveis (% sobre o total de pais o...                                                 32
# Crianças e adolescentes (% sobre o total de usu...                                                 22
#
#                                                                                               2  \
# Resposta                                            Privacidade/Não passar informações pessoais
# ...

# %% [markdown]
# ### 9. Apresente em tela somente a 1ª e a 2ª coluna (rótulo) da base de dados.

# %%
# O código a seguir seleciona as primeiras duas colunas do DataFrame usando a função .iloc.
# A notação .iloc[:, 0:2] é utilizada para acessar todas as linhas (:) e as colunas de índice 0 até 1 (o índice final é excluído, ou seja, até a segunda coluna).
# Isso pode ser útil quando se deseja focar em um subconjunto específico de dados, neste caso, as duas primeiras colunas da tabela.
import pandas as pd

percepcao_sobre_o_uso_seguro_da_internet_df = pd.read_excel("dados_detalhados_internet.xlsx") #Ler a tabela

percepcao_sobre_o_uso_seguro_da_internet_df.iloc[:, 0:2]
# Out:
#                                             Resposta  \
# 0                Não falar com pessoas desconhecidas
# 1  Não entrar em sites que tenham conteúdos sexua...
# 2        Privacidade/Não passar informações pessoais
# 3        Sites inapropriados para a idade dos filhos
# 4          Não entrar em sites com conteúdo violento
# 5                                  Cuidado com vírus
# 6                             Ter cuidado com senhas
# 7                            Ter cuidado com hackers
# 8                                             Outros
# 9                                            Não sei
#
#    Pais ou Responsáveis (% sobre o total de pais ou responsáveis)
# 0                                                 55
# 1                                                 32
# 2                                                 31
# 3                                                 31
# 4                                                 17
# ...

# %% [markdown]
# ### 10. Informe como foi desenvolvido o Projeto e comente um gráfico gerado por você sobre a análise de dados.
#
# Empregamos uma abordagem diversificada na coleta e processamento de dados, combinando diferentes métodos e ferramentas para garantir precisão e eficiência. Para a pesquisa de referências e informações relevantes, utilizamos tanto o Google convencional quanto o Google Acadêmico, permitindo um levantamento abrangente e criterioso das fontes.
#
# A etapa de processamento e análise de dados foi conduzida com a linguagem de programação Python dentro do ambiente Google Colab, proporcionando uma infraestrutura flexível e acessível para execução dos scripts. Contamos com o suporte do ChatGPT, especialmente para a otimização, estruturação e formatação dos dados, garantindo maior eficiência no tratamento das informações. Além disso, utilizamos a biblioteca Pandas, amplamente reconhecida no campo da ciência de dados, para manipulação, limpeza e organização dos datasets, assegurando uma abordagem estruturada e confiável na análise.
#
# Um dos principais desafios do nosso projeto foi a obtenção de dados válidos. Embora a internet ofereça uma vasta quantidade de informações, nem todas são autenticas ou se encontram atualizadas.
#
# --
#
#
#
#
#
# Utilizamos o artigo ["Classificação Indicativa e
# Novas Mídias" ](https://www.gov.br/mj/pt-br/assuntos/seus-direitos/classificacao-1/volume_3.pdf#page=100)  Como referência para os dados coletados do projeto

# %% [markdown]
# ## Gráfico
#
# Nosso gráfico compara as respostas de pais e responsáveis com as de crianças e adolescentes, evidenciando diferenças no nível de conhecimento sobre segurança virtual. De modo geral, os responsáveis demonstraram maior conhecimento sobre as prevenções na internet, exceto em aspectos específicos, como proteção contra vírus e gerenciamento de senhas, nos quais as crianças se sobressaíram. Esse resultado sugere que grande parte do conhecimento das crianças sobre segurança digital é influenciada diretamente pelo nível de conscientização e orientação de seus responsáveis.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregar os dados do arquivo XLSX
df = pd.read_excel("dados_detalhados_internet.xlsx", sheet_name="Sheet1")

# Renomear as colunas para facilitar o uso
df.columns = ["Resposta", "Pais ou Responsáveis (%)", "Crianças e adolescentes (%)"]

# Transformar os dados para o formato longo (ideal para Seaborn)
df_long = df.melt(id_vars="Resposta", var_name="Grupo", value_name="Porcentagem")

# Criar o gráfico de barras agrupadas
plt.figure(figsize=(12, 8))
sns.barplot(
    x="Resposta",
    y="Porcentagem",
    hue="Grupo",
    data=df_long,
    palette="coolwarm",  # Paleta de cores moderna
)

# Adicionar título e labels
plt.title("Comparação de Respostas entre Pais/Responsáveis e Crianças/Adolescentes", fontsize=16)
plt.xlabel("Respostas", fontsize=12)
plt.ylabel("Porcentagem (%)", fontsize=12)

# Rotacionar os rótulos do eixo X para melhorar a legibilidade
plt.xticks(rotation=45, ha="right")

# Ajustar a legenda
plt.legend(title="Grupo", bbox_to_anchor=(1.05, 1), loc='upper left')

# Melhorar a visualização dos eixos
plt.grid(True, linestyle='--', alpha=0.7, axis="y")

# Ajustar o layout para evitar cortes
plt.tight_layout()

# Mostrar o gráfico
plt.show()
